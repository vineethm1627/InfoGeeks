# %% [markdown]
# ## Installing PyGithub

# %%
# %pip install PyGithub

# %%
from github import Github 

g = Github()

userquery=input('Enter your search query-')

sort_flag=input('Do you want to sort the results based on the number of stars on the repositories? (y/n)-')
tup=[]
def extract_repos(userquery):
    
    repositories = g.search_repositories(query=userquery)
    for i in range(100):
        url='https://github.com/{}'.format(repositories[i].full_name)
        #print(url)
        stars_count=repositories[i].stargazers_count
       # print('Number of Stars on the repo=', stars_count)
        tup.append([url, stars_count])
        

def sortfun(Tuple):
    Tuple=sorted(Tuple, key=lambda x:x[1], reverse=True)
    return Tuple

def apply_sort(flag, Tuple):
    if(flag=='y'):
        new_tup=sortfun(Tuple)
    for i in  new_tup:
        print(i)
    
extract_repos(userquery)

apply_sort(sort_flag, tup)
# Out:
# Enter your search query-python
# Do you want to sort the results based on the number of stars on the repositories? (y/n)-y
# ['https://github.com/TheAlgorithms/Python', 102216]
# ['https://github.com/jackfrued/Python-100-Days', 101667]
# ['https://github.com/vinta/awesome-python', 95926]
# ['https://github.com/scikit-learn/scikit-learn', 45379]
# ['https://github.com/python/cpython', 37300]
# ['https://github.com/jakevdp/PythonDataScienceHandbook', 28809]
# ['https://github.com/faif/python-patterns', 28081]
# ['https://github.com/realpython/python-guide', 22821]
# ['https://github.com/geekcomputers/Python', 22305]
# ['https://github.com/gto76/python-cheatsheet', 22059]
# ['https://github.com/jobbole/awesome-python-cn', 21968]
# ['https://github.com/google/python-fire', 18956]
# ['https://github.com/Pierian-Data/Complete-Python-3-Bootcamp', 15452]
# ['https://github.com/zhiwehu/Python-programming-exercises', 15134]
# ['https://github.com/python-telegram-bot/python-telegram-bot', 14410]
# ['https://github.com/taizilongxu/interview_python', 13880]
# ['https://github.com/matplotlib/matplotlib', 13469]
# ['https://github.com/alievk/avatarify-python', 13282]
# ['https://github.com/Kr1s77/awesome-python-login-model', 13181]
# ['https://github.com/Jack-Cherish/python-spider', 12832]
# ['https://github.com/mahmoud/awesome-python-applications', 12597]
# ['https://github.com/fchollet/deep-learning-with-python-notebooks', 12416]
# ['https://github.com/AtsushiSakai/PythonRobotics', 12032]
# ['https://github.com/rasbt/python-machine-learning-book', 11160]
# ['https://github.com/yidao620c/python3-cookbook', 9119]
# ['https://github.com/TwoWater/Python', 9065]
# ['https://github.com/dabeaz-course/practical-python', 7237]
# ['https://github.com/trekhleb/learn-python', 7127]
# ['https://github.com/injetlee/Python', 6612]
# ['https://github.com/wistbean/learn_python3_spider', 6608]
# ['https://github.com/kivy/python-for-android', 6445]
# ['https://github.com/Asabeneh/30-Days-Of-Python', 6095]
# ['https://github.com/jackzhenguo/python-small-examples', 6017]
# ['https://github.com/lijin-THU/notes-python', 5891]
# ['https://github.com/xianhu/LearnPython', 5608]
# ['https://github.com/aimacode/aima-python', 5538]
# ['https://github.com/amueller/introduction_to_ml_with_python', 5377]
# ['https://github.com/lancopku/pkuseg-python', 5363]
# ['https://github.com/lining0806/PythonSpiderNotes', 5349]
# ['https://github.com/python-mode/python-mode', 5193]
# ['https://github.com/michaelliao/learn-python3', 5072]
# ['https://github.com/GoogleCloudPlatform/python-docs-samples', 4943]
# ['https://github.com/googleapis/google-api-python-client', 4627]
# ['https://github.com/coodict/python3-in-one-pic', 4356]
# ['https://github.com/gregmalcolm/python_koans', 4333]
# ['https://github.com/dpkp/kafka-python', 4323]
# ['https://github.com/dibgerge/ml-coursera-python-assignments', 4106]
# ['https://github.com/lawlite19/MachineLearning_Python', 3797]
# ['https://github.com/jerry-git/learn-python3', 3696]
# ['https://github.com/Alfred1984/interesting-python', 3659]
# ['https://github.com/arogozhnikov/python3_with_pleasure', 3633]
# ['https://github.com/kubernetes-client/python', 3606]
# ['https://github.com/REMitchell/python-scraping', 3287]
# ['https://github.com/dabeaz/python-cookbook', 3155]
# ['https://github.com/bear/python-twitter', 3153]
# ['https://github.com/Show-Me-the-Code/python', 3125]
# ['https://github.com/susanli2016/Machine-Learning-with-Python', 2949]
# ['https://github.com/JWarmenhoven/ISLR-python', 2900]
# ['https://github.com/sammchardy/python-binance', 2894]
# ['https://github.com/facebookarchive/python-instagram', 2843]
# ['https://github.com/xxg1413/python', 2315]
# ['https://github.com/michaelliao/awesome-python3-webapp', 2015]
# ['https://github.com/Jack-Cherish/PythonPark', 2001]
# ['https://github.com/codebasics/py', 1999]
# ['https://github.com/DonJayamanne/pythonVSCode', 1982]
# ['https://github.com/marblexu/PythonPlantsVsZombies', 1930]
# ['https://github.com/wkunzhi/Python3-Spider', 1874]
# ['https://github.com/jmportilla/Complete-Python-Bootcamp', 1753]
# ['https://github.com/revolunet/PythonBooks', 1699]
# ['https://github.com/docker-library/python', 1621]
# ['https://github.com/dsacademybr/PythonFundamentos', 967]
# ['https://github.com/joeyajames/Python', 933]
# ['https://github.com/exercism/python', 929]
# ['https://github.com/yhangf/PythonCrawler', 867]
# ['https://github.com/521xueweihan/python', 768]
# ['https://github.com/joe011/python', 672]
# ['https://github.com/gxcuizy/Python', 649]
# ['https://github.com/hussien89aa/PythonTutorial', 592]
# ['https://github.com/poise/python', 528]
# ['https://github.com/zhanghe06/python', 463]
# ['https://github.com/nnja/python', 335]
# ['https://github.com/boostorg/python', 309]
# ['https://github.com/Tanu-N-Prabhu/Python', 305]
# ['https://github.com/Yonv1943/Python', 276]
# ['https://github.com/bigmlcom/python', 264]
# ['https://github.com/17mon/python', 216]
# ['https://github.com/heyxiaohao/Python', 205]
# ['https://github.com/Snailclimb/python', 203]
# ['https://github.com/vipstone/python', 148]
# ['https://github.com/pubnub/python', 141]
# ['https://github.com/AllAlgorithms/python', 134]
# ['https://github.com/smilejay/python', 125]
# ['https://github.com/albertlauncher/python', 113]
# ['https://github.com/ThatEidolon/Python', 109]
# ['https://github.com/EdwinZhang1970/Python', 102]
# ['https://github.com/roytuts/python', 100]
# ['https://github.com/jerrywu2013/Python', 93]
# ['https://github.com/Shekhar-rv/Python', 65]
# ['https://github.com/pluralsight-projects/PythonFlask-JobBoard', 37]
# ['https://github.com/adi0509/Python', 10]
